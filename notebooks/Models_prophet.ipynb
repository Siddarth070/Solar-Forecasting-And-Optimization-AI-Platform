# %%
import pandas as pd

# %%
df = pd.read_parquet('/content/drive/MyDrive/Saved from Chrome/jaipur_features_90d.parquet')

# %%
df.columns
# Out:
# Index(['temperature_2m', 'relative_humidity_2m', 'precipitation',
#        'cloud_cover', 'wind_speed_10m', 'shortwave_radiation',
#        'direct_radiation', 'diffuse_radiation', 'solar_output_mw',
#        'clear_sky_ghi', 'hour', 'day_of_week', 'month', 'is_daytime',
#        'hour sin', 'hour cos', 'month sin', 'month cos', 'solar_lag_1h',
#        'solar_lag_24h', 'solar_lag_48h', 'solar_lag_168h',
#        'solar_rolling_mean_3h', 'solar_rolling_mean_6h',
#        'solar_rolling_std_3h', 'clear_sky_output', 'clear_sky_ratio'],
#       dtype='object')

# %%
df = df.rename(columns = {
    'hour sin' : 'hour_sin',
    'hour cos' : 'hour_cos',
    'month sin' : 'month_sin',
    'month cos' : 'month_cos'
})

# %%
df.columns
# Out:
# Index(['temperature_2m', 'relative_humidity_2m', 'precipitation',
#        'cloud_cover', 'wind_speed_10m', 'shortwave_radiation',
#        'direct_radiation', 'diffuse_radiation', 'solar_output_mw',
#        'clear_sky_ghi', 'hour', 'day_of_week', 'month', 'is_daytime',
#        'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'solar_lag_1h',
#        'solar_lag_24h', 'solar_lag_48h', 'solar_lag_168h',
#        'solar_rolling_mean_3h', 'solar_rolling_mean_6h',
#        'solar_rolling_std_3h', 'clear_sky_output', 'clear_sky_ratio'],
#       dtype='object')

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %%
n = len(df)
train_end = int(n * 0.70)
val_end   = int(n * 0.85)

train = df.iloc[:train_end]
val   = df.iloc[train_end:val_end]
test  = df.iloc[val_end:]

print(f"Train: {len(train)} rows")
print(f"Val:   {len(val)} rows")
print(f"Test:  {len(test)} rows")
# Out:
# Train: 1394 rows
# Val:   299 rows
# Test:  299 rows

# %%
def create_sequences(X, y, lookback=24):

    X_seq, y_seq = [], []

    for i in range(lookback, len(X)):
        X_seq.append(X[i-lookback:i])
        y_seq.append(y[i])

    return np.array(X_seq), np.array(y_seq)


feature_cols = ['shortwave_radiation',
    'cloud_cover',
    'temperature_2m',
    'relative_humidity_2m',
    'wind_speed_10m',
    'hour_sin', 'hour_cos',
    'month_sin', 'month_cos',
    'solar_lag_1h',
    'solar_lag_24h',
    'solar_lag_48h',
    'solar_lag_168h',
    'solar_rolling_mean_3h',
    'solar_rolling_mean_6h',
    'solar_rolling_std_3h',
    'clear_sky_ratio']

target_col = 'solar_output_mw'
LOOKBACK = 24

X_train_seq, y_train_seq = create_sequences(
    train[feature_cols].values,
    train[target_col].values,
    LOOKBACK
)

X_val_seq, y_val_seq = create_sequences(
    val[feature_cols].values,
    val[target_col].values,
    LOOKBACK
)

X_test_seq, y_test_seq = create_sequences(
    test[feature_cols].values,
    test[target_col].values,
    LOOKBACK
)

print("X_train_seq shape:", X_train_seq.shape)
print("X_val_seq shape:  ", X_val_seq.shape)
print("X_test_seq shape: ", X_test_seq.shape)
# Out:
# X_train_seq shape: (1370, 24, 17)
# X_val_seq shape:   (275, 24, 17)
# X_test_seq shape:  (275, 24, 17)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(
    train[feature_cols].values
)
y_train_scaled = scaler_y.fit_transform(
    train[[target_col]].values
)

X_val_scaled = scaler_X.transform(val[feature_cols].values)
y_val_scaled = scaler_y.transform(val[[target_col]].values)

X_test_scaled = scaler_X.transform(test[feature_cols].values)
y_test_scaled = scaler_y.transform(test[[target_col]].values)

X_train_seq, y_train_seq = create_sequences(
    X_train_scaled, y_train_scaled.flatten(),
    LOOKBACK
)
X_val_seq, y_val_seq = create_sequences(
    X_val_scaled, y_val_scaled.flatten(),
    LOOKBACK
)
X_test_seq, y_test_seq = create_sequences(
    X_test_scaled, y_test_scaled.flatten(),
    LOOKBACK
)

print("Scaling complete")
print("X_train_seq shape:", X_train_seq.shape)
print("y_train_seq range:", y_train_seq.min().round(2),
      "to", y_train_seq.max().round(2))
# Out:
# Scaling complete
# X_train_seq shape: (1370, 24, 17)
# y_train_seq range: 0.0 to 1.0

# %%
n_features = X_train_seq.shape[2]
n_lookback = X_train_seq.shape[1]

model_lstm = Sequential([
    LSTM(64,
         return_sequences=True,
         input_shape=(n_lookback, n_features)),
    Dropout(0.2),


    LSTM(32,
         return_sequences=False),
    Dropout(0.2),

    Dense(16, activation='relu'),
    Dense(1)
])

model_lstm.compile(
    optimizer='adam',
    loss='mae'
)

model_lstm.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 24, 64)         │        20,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,953 (132.63 KB)
#  Trainable params: 33,953 (132.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

history = model_lstm.fit(
    X_train_seq, y_train_seq,
    epochs=100,
    batch_size=32,
    validation_data=(X_val_seq, y_val_seq),
    callbacks=[early_stop],
    verbose=1
)

print("Training complete")
# Out:
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.1580 - val_loss: 0.0538
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0656 - val_loss: 0.0315
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0518 - val_loss: 0.0197
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0452 - val_loss: 0.0279
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0415 - val_loss: 0.0232
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0372 - val_loss: 0.0123
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0389 - val_loss: 0.0446
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0429 - val_loss: 0.0144
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0360 - val_loss: 0.0192
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0341 - val_loss: 0.0160
# Epoch 11/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0355 - val_loss: 0.0296
# Epoch 12/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0344 - val_loss: 0.0164
# Epoch 13/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0303 - val_loss: 0.0194
# Epoch 14/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0295 - val_loss: 0.0244
# Epoch 15/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0299 - val_loss: 0.0109
# Epoch 16/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0302 - val_loss: 0.0213
# Epoch 17/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0294 - val_loss: 0.0147
# Epoch 18/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0273 - val_loss: 0.0234
# Epoch 19/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0273 - val_loss: 0.0137
# Epoch 20/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0262 - val_loss: 0.0155
# Epoch 21/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0253 - val_loss: 0.0124
# Epoch 22/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0240 - val_loss: 0.0108
# Epoch 23/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0258 - val_loss: 0.0102
# Epoch 24/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0252 - val_loss: 0.0099
# Epoch 25/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0239 - val_loss: 0.0109
# Epoch 26/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0219 - val_loss: 0.0123
# Epoch 27/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0223 - val_loss: 0.0254
# Epoch 28/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0211 - val_loss: 0.0142
# Epoch 29/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0218 - val_loss: 0.0162
# Epoch 30/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0250 - val_loss: 0.0114
# Epoch 31/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0210 - val_loss: 0.0127
# Epoch 32/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0193 - val_loss: 0.0141
# Epoch 33/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0204 - val_loss: 0.0156
# Epoch 34/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0218 - val_loss: 0.0204
# Training complete

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

y_pred_scaled = model_lstm.predict(X_val_seq)

y_pred_lstm = scaler_y.inverse_transform(y_pred_scaled).flatten()
y_actual = scaler_y.inverse_transform(
    y_val_seq.reshape(-1,1)
).flatten()

mae  = mean_absolute_error(y_actual, y_pred_lstm)
rmse = np.sqrt(mean_squared_error(y_actual, y_pred_lstm))

daytime_mask = y_actual > 1.0
mape = np.mean(
    np.abs((y_actual[daytime_mask] - y_pred_lstm[daytime_mask]) /
            y_actual[daytime_mask])
) * 100

print("LSTM Results:")
print(f"MAE:  {mae:.2f} MW")
print(f"RMSE: {rmse:.2f} MW")
print(f"MAPE: {mape:.2f}%")

print("\nXGBoost Results (for comparison):")
print("MAE:  0.25 MW")
print("RMSE: 0.48 MW")
print("MAPE: 2.17%")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# LSTM Results:
# MAE:  0.60 MW
# RMSE: 0.99 MW
# MAPE: 5.31%
#
# XGBoost Results (for comparison):
# MAE:  0.25 MW
# RMSE: 0.48 MW
# MAPE: 2.17%

# %%
plt.figure(figsize=(14, 5))
plt.plot(y_actual[:168], label='Actual', linewidth=1)
plt.plot(y_pred_lstm[:168], label='LSTM Predicted',
         linewidth=1, alpha=0.8)
plt.title('LSTM — Predicted vs Actual (first 7 days)')
plt.xlabel('Hour')
plt.ylabel('Solar output (MW)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.axvline(x=23, color='red', linestyle='--',
            label='Best epoch (24)')
plt.title('LSTM Training History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
model_lstm.save(
    '/content/drive/MyDrive/lstm_solar_v1.keras'
)
print("LSTM model saved to Drive")
# Out:
# LSTM model saved to Drive

# %%
df.columns
# Out:
# Index(['temperature_2m', 'relative_humidity_2m', 'precipitation',
#        'cloud_cover', 'wind_speed_10m', 'shortwave_radiation',
#        'direct_radiation', 'diffuse_radiation', 'solar_output_mw',
#        'clear_sky_ghi', 'hour', 'day_of_week', 'month', 'is_daytime',
#        'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'solar_lag_1h',
#        'solar_lag_24h', 'solar_lag_48h', 'solar_lag_168h',
#        'solar_rolling_mean_3h', 'solar_rolling_mean_6h',
#        'solar_rolling_std_3h', 'clear_sky_output', 'clear_sky_ratio'],
#       dtype='object')

# %%
# !pip install prophet -q

# %%
from prophet import Prophet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_prophet = df.reset_index()[['index', 'solar_output_mw']].copy()
df_prophet.columns = ['ds', 'y']

df_prophet['ds'] = df_prophet['ds'].dt.tz_localize(None)

print("Prophet data shape:", df_prophet.shape)
print("\nFirst few rows:")
print(df_prophet.head())
print("\nDate range:", df_prophet['ds'].min(),
      "to", df_prophet['ds'].max())
# Out:
# Prophet data shape: (1992, 2)
#
# First few rows:
#                    ds    y
# 0 2024-01-08 00:00:00  0.0
# 1 2024-01-08 01:00:00  0.0
# 2 2024-01-08 02:00:00  0.0
# 3 2024-01-08 03:00:00  0.0
# 4 2024-01-08 04:00:00  0.0
#
# Date range: 2024-01-08 00:00:00 to 2024-03-30 23:00:00

# %%
df_prophet = df.reset_index()[['index', 'solar_output_mw']].copy()
df_prophet.columns = ['ds', 'y']

df_prophet['ds'] = df_prophet['ds'].dt.tz_localize(None)

# %%
n = len(df_prophet)
train_end = int(n * 0.70)
val_end   = int(n * 0.85)

train_prophet = df_prophet.iloc[:train_end]
val_prophet   = df_prophet.iloc[train_end:val_end]
test_prophet  = df_prophet.iloc[val_end:]

print(f"Train: {len(train_prophet)} rows")
print(f"Val:   {len(val_prophet)} rows")
print(f"Test:  {len(test_prophet)} rows")
# Out:
# Train: 1394 rows
# Val:   299 rows
# Test:  299 rows

# %%
model_prophet = Prophet(
    daily_seasonality=True,
    weekly_seasonality=False,
    yearly_seasonality=False,
    seasonality_mode='multiplicative',
    changepoint_prior_scale=0.05
)


model_prophet.fit(train_prophet)

print("Prophet training complete")
# Out:
# Prophet training complete

# %%
future = model_prophet.make_future_dataframe(
    periods=len(val_prophet),
    freq='h'
)


forecast = model_prophet.predict(future)

print("Forecast columns:", list(forecast.columns))
print("\nKey forecast output:")
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(20))
# Out:
# Forecast columns: ['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper', 'daily', 'daily_lower', 'daily_upper', 'multiplicative_terms', 'multiplicative_terms_lower', 'multiplicative_terms_upper', 'additive_terms', 'additive_terms_lower', 'additive_terms_upper', 'yhat']
#
# Key forecast output:
#                       ds       yhat  yhat_lower  yhat_upper
# 1673 2024-03-17 17:00:00  24.420761   22.520235   26.152094
# 1674 2024-03-17 18:00:00   9.926724    8.547191   11.272555
# 1675 2024-03-17 19:00:00   1.085334   -0.135755    2.259587
# 1676 2024-03-17 20:00:00  -1.427287   -2.631852   -0.305927
# 1677 2024-03-17 21:00:00  -0.335396   -1.541543    0.792710
# 1678 2024-03-17 22:00:00   0.807179   -0.462767    1.953267
# 1679 2024-03-17 23:00:00   0.425298   -0.849774    1.567425
# 1680 2024-03-18 00:00:00  -0.543441   -1.789726    0.746192
# 1681 2024-03-18 01:00:00  -0.560011   -1.827621    0.717211
# 1682 2024-03-18 02:00:00   0.394486   -0.777786    1.610835
# 1683 2024-03-18 03:00:00   0.798708   -0.356197    2.005737
# 1684 2024-03-18 04:00:00  -0.306984   -1.579776    0.827766
# 1685 2024-03-18 05:00:00  -1.387932   -2.571914   -0.188538
# 1686 2024-03-18 06:00:00   1.091918   -0.107225    2.292134
# 1687 2024-03-18 07:00:00   9.882204    8.488910   11.191795
# 1688 2024-03-18 08:00:00  24.355988   22.362250   26.169585
# 1689 2024-03-18 09:00:00  40.564438   37.832616   43.037502
# 1690 2024-03-18 10:00:00  53.932379   50.399603   57.108720
# 1691 2024-03-18 11:00:00  62.132164   58.261627   66.112397
# 1692 2024-03-18 12:00:00  65.619303   61.369321   69.560903

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error


val_start_idx = len(train_prophet)
val_predictions = forecast['yhat'].iloc[val_start_idx:val_start_idx + len(val_prophet)].values
val_actual = val_prophet['y'].values


val_predictions = np.clip(val_predictions, 0, None)


mae  = mean_absolute_error(val_actual, val_predictions)
rmse = np.sqrt(mean_squared_error(val_actual, val_predictions))

daytime_mask = val_actual > 1.0
mape = np.mean(
    np.abs((val_actual[daytime_mask] - val_predictions[daytime_mask]) /
            val_actual[daytime_mask])
) * 100

print("Prophet Results:")
print(f"MAE:  {mae:.2f} MW")
print(f"RMSE: {rmse:.2f} MW")
print(f"MAPE: {mape:.2f}%")

print("\nComparison:")
print(f"XGBoost: MAE 0.25 MW | MAPE 2.17%")
print(f"LSTM:    MAE 0.60 MW | MAPE 5.31%")
# Out:
# Prophet Results:
# MAE:  1.30 MW
# RMSE: 2.01 MW
# MAPE: 7.00%
#
# Comparison:
# XGBoost: MAE 0.25 MW | MAPE 2.17%
# LSTM:    MAE 0.60 MW | MAPE 5.31%

# %%
model_prophet.plot(forecast)
plt.title('Prophet Solar Output Forecast')
plt.show()


model_prophet.plot_components(forecast)
plt.show()

# %%
import pickle

# Save to Drive
with open('/content/drive/MyDrive/prophet_solar_v1.pkl', 'wb') as f:
    pickle.dump(model_prophet, f)

print("Prophet model saved")
# Out:
# Prophet model saved
